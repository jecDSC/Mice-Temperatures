# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
mice = pd.read_csv('Mouse_Data_Student_Copy.xlsx - Fem Act.csv')
mice2 = pd.read_csv('Mouse_Data_Student_Copy.xlsx - Male Temp.csv')

# %%
mice.head()
test = mice2.iloc[:1440]

# %%
px.line(test, y='m6')
